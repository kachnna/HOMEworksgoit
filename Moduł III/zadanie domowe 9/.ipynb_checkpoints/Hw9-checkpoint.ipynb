# %% [markdown]
# # Fashion MNIST
# Fashion-MNIST to zbiór danych obrazów artykułów Zalando składający się z zestawu szkoleniowego zawierającego 60 000 przykładów i zestawu testowego zawierającego 10 000 przykładów. Każdy przykład to obraz w skali szarości 28x28, powiązany z etykietą z 10 klas.

# %%
import keras
import tensorflow as tf
from tensorflow.keras import layers, models, datasets
import numpy as np
import matplotlib.pyplot as plt

# Załadowanie danych
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Sprawdzenie kształtów danych
assert x_train.shape == (60000, 28, 28)
assert x_test.shape == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)

# Normalizacja i reshaping danych
x_train = x_train.reshape(-1, 28*28).astype('float32') / 255.
x_test = x_test.reshape(-1, 28*28).astype('float32') / 255.

# Tworzenie modelu
model = models.Sequential([
    layers.Input(shape=(28*28,)),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

# Kompilacja modelu
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Trening modelu
history = model.fit(
    x_train, y_train,
    epochs=30,
    batch_size=256,
    validation_data=(x_test, y_test),
    verbose=2
)

# Ocena modelu na danych testowych
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f"Dokładność na zbiorze testowym: {test_accuracy:.4f}")

# Wykres historii treningu
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/30
# 235/235 - 4s - 18ms/step - accuracy: 0.8022 - loss: 0.5609 - val_accuracy: 0.8421 - val_loss: 0.4495
# Epoch 2/30
# 235/235 - 3s - 14ms/step - accuracy: 0.8582 - loss: 0.3909 - val_accuracy: 0.8659 - val_loss: 0.3813
# Epoch 3/30
# 235/235 - 3s - 14ms/step - accuracy: 0.8703 - loss: 0.3543 - val_accuracy: 0.8563 - val_loss: 0.3827
# Epoch 4/30
# 235/235 - 4s - 17ms/step - accuracy: 0.8783 - loss: 0.3306 - val_accuracy: 0.8726 - val_loss: 0.3548
# Epoch 5/30
# 235/235 - 4s - 15ms/step - accuracy: 0.8866 - loss: 0.3090 - val_accuracy: 0.8741 - val_loss: 0.3415
# Epoch 6/30
# 235/235 - 3s - 15ms/step - accuracy: 0.8872 - loss: 0.3004 - val_accuracy: 0.8794 - val_loss: 0.3376
# Epoch 7/30
# 235/235 - 3s - 13ms/step - accuracy: 0.8941 - loss: 0.2859 - val_accuracy: 0.8780 - val_loss: 0.3364
# Epoch 8/30
# 235/235 - 3s - 12ms/step - accuracy: 0.8954 - loss: 0.2791 - val_accuracy: 0.8797 - val_loss: 0.3321
# Epoch 9/30
# 235/235 - 3s - 13ms/step - accuracy: 0.8999 - loss: 0.2668 - val_accuracy: 0.8815 - val_loss: 0.3341
# Epoch 10/30
# 235/235 - 3s - 12ms/step - accuracy: 0.9023 - loss: 0.2607 - val_accuracy: 0.8844 - val_loss: 0.3210
# Epoch 11/30
# 235/235 - 3s - 12ms/step - accuracy: 0.9043 - loss: 0.2535 - val_accuracy: 0.8890 - val_loss: 0.3185
# Epoch 12/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9069 - loss: 0.2467 - val_accuracy: 0.8873 - val_loss: 0.3200
# Epoch 13/30
# 235/235 - 3s - 12ms/step - accuracy: 0.9088 - loss: 0.2413 - val_accuracy: 0.8916 - val_loss: 0.3121
# Epoch 14/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9117 - loss: 0.2339 - val_accuracy: 0.8849 - val_loss: 0.3178
# Epoch 15/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9136 - loss: 0.2310 - val_accuracy: 0.8815 - val_loss: 0.3347
# Epoch 16/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9133 - loss: 0.2273 - val_accuracy: 0.8937 - val_loss: 0.3040
# Epoch 17/30
# 235/235 - 3s - 14ms/step - accuracy: 0.9180 - loss: 0.2169 - val_accuracy: 0.8934 - val_loss: 0.3100
# Epoch 18/30
# 235/235 - 4s - 16ms/step - accuracy: 0.9185 - loss: 0.2140 - val_accuracy: 0.8903 - val_loss: 0.3221
# Epoch 19/30
# 235/235 - 3s - 15ms/step - accuracy: 0.9195 - loss: 0.2109 - val_accuracy: 0.8926 - val_loss: 0.3207
# Epoch 20/30
# 235/235 - 3s - 14ms/step - accuracy: 0.9217 - loss: 0.2078 - val_accuracy: 0.8955 - val_loss: 0.3139
# Epoch 21/30
# 235/235 - 3s - 14ms/step - accuracy: 0.9221 - loss: 0.2036 - val_accuracy: 0.8887 - val_loss: 0.3194
# Epoch 22/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9249 - loss: 0.1975 - val_accuracy: 0.8972 - val_loss: 0.3142
# Epoch 23/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9274 - loss: 0.1934 - val_accuracy: 0.8930 - val_loss: 0.3193
# Epoch 24/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9263 - loss: 0.1920 - val_accuracy: 0.8952 - val_loss: 0.3111
# Epoch 25/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9287 - loss: 0.1851 - val_accuracy: 0.8935 - val_loss: 0.3151
# Epoch 26/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9298 - loss: 0.1839 - val_accuracy: 0.8951 - val_loss: 0.3174
# Epoch 27/30
# 235/235 - 3s - 14ms/step - accuracy: 0.9297 - loss: 0.1841 - val_accuracy: 0.8990 - val_loss: 0.3166
# Epoch 28/30
# 235/235 - 3s - 14ms/step - accuracy: 0.9320 - loss: 0.1781 - val_accuracy: 0.8996 - val_loss: 0.3168
# Epoch 29/30
# 235/235 - 3s - 13ms/step - accuracy: 0.9330 - loss: 0.1759 - val_accuracy: 0.8960 - val_loss: 0.3210
# Epoch 30/30
# 235/235 - 4s - 15ms/step - accuracy: 0.9333 - loss: 0.1750 - val_accuracy: 0.8963 - val_loss: 0.3184
# 313/313 - 1s - 2ms/step - accuracy: 0.8963 - loss: 0.3184
# Dokładność na zbiorze testowym: 0.8963
